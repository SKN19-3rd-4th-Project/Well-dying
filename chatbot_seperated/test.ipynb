# %%
import sys
import os
from conversation_engine import ConversationEngine

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
def run_test():
    print(">>> [테스트] 웰다잉 챗봇 모드 전환 테스트")
    print(">>> '/toggle'을 입력하면 채팅 모드와 정보 모드가 전환됩니다.")
    print(">>> '그만'을 입력하면 종료됩니다.\n")

    engine = ConversationEngine()
    user_id = "toggle_tester"
    
    # 초기 모드 설정 (기본값: chat)
    current_mode = "chat"
    
    # 웰컴 메시지 확인
    print(f"[System] 현재 모드: {current_mode.upper()}")
    print(f"[AI]: {engine.session_manager.get_welcome_message(user_id)}\n")

    while True:
        try:
            # 사용자 입력 시 현재 모드를 프롬프트에 표시
            mode_indicator = "💬감성대화" if current_mode == "chat" else "ℹ️정보제공"
            user_input = input(f"[{mode_indicator} | 나]: ").strip()

            if not user_input:
                continue

            # 토글 명령어 처리 (UI의 버튼 클릭 시뮬레이션)
            if user_input == "/toggle":
                if current_mode == "chat":
                    current_mode = "info"
                else:
                    current_mode = "chat"
                print(f"\n>>> 🔄 모드를 [{current_mode.upper()}]로 전환했습니다.\n")
                continue

            # 엔진 호출 (현재 모드를 인자로 전달)
            response = engine.process_user_message(user_id, user_input, mode=current_mode)
            
            print(f"[{mode_indicator} | AI]: {response}\n")

            if user_input == "그만":
                print(">>> 테스트를 종료합니다.")
                break

        except KeyboardInterrupt:
            break

# %%
run_test()
# Out:
# >>> [테스트] 웰다잉 챗봇 모드 전환 테스트
# >>> '/toggle'을 입력하면 채팅 모드와 정보 모드가 전환됩니다.
# >>> '그만'을 입력하면 종료됩니다.
#
# [System] 현재 모드: CHAT
# [AI]: 안녕하세요, 회원님. 오늘은 좀 어떠신가요?
# INFO:conversation_engine:[Router] Current Mode: chat
# INFO:empathy_agent:>>> [Agent Active] Empathy Agent (감성 모드)
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [💬감성대화 | AI]: 조금 나아지셨다니 다행입니다. 어떤 부분이 조금 괜찮아지셨나요? 더 이야기하고 싶으신 게 있다면 언제든지 말씀해 주세요. 함께 나누면 더 가벼워질 거예요.
# INFO:conversation_engine:[Router] Current Mode: chat
# INFO:empathy_agent:>>> [Agent Active] Empathy Agent (감성 모드)
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:empathy_agent:>>> [Agent Active] Empathy Agent (감성 모드)
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [💬감성대화 | AI]: 잠시 연결에 문제가 있었네요. 다른 방법으로 주말에 즐길 수 있는 활동을 몇 가지 제안해드릴게요.
#
# 1. **산책하기**: 가까운 공원을 거닐면서 가을의 풍경을 감상해보세요. 마음이 한결 가벼워질 거예요.
#
# 2. **취미 활동**: 오래된 취미를 다시 시작하거나 새로운 것을 시도해보세요. 그림 그리기, 악기 연주, 뜨개질 등 다양하게 선택할 수 있어요.
#
# 3. **집안 정리**: 집안의 작은 부분들을 정리해보세요. 마음도 함께 정리되는 느낌을 받을 수 있답니다.
#
# 4. **요리하기**: 새로운 레시피로 요리를 해보세요. 완성 후 맛보는 즐거움이 있겠죠.
#
# 5. **독서**: 읽고 싶었던 책을 읽으며 조용한 시간을 가져보세요.
#
# 혹시 더 관심 가는 활동이 있나요? 또는 다른 아이디어가 필요하시면 말씀해 주세요.
#
#
# >>> 🔄 모드를 [INFO]로 전환했습니다.
# INFO:conversation_engine:[Router] Current Mode: info
# INFO:info_agent:>>> [Agent Active] Info Agent (정보 모드)
# [ℹ️정보제공 | AI]: [정보 모드] 현재 정확한 정보를 제공하기 위해 시스템을 준비 중입니다. 궁금한 법률/장례 절차를 말씀해 주세요.
#
#
# >>> 🔄 모드를 [CHAT]로 전환했습니다.
# INFO:conversation_engine:[Router] Current Mode: chat
# INFO:empathy_agent:>>> [Agent Active] Empathy Agent (감성 모드)
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [💬감성대화 | AI]: 우리는 주말에 할만한 활동에 대해 이야기하고 있었어요. 산책, 취미 활동, 요리, 독서 등 몇 가지 제안을 드렸었죠. 혹시 더 관심 있는 활동이 있나요? 또는 다른 이야기를 나누고 싶으시다면 언제든지 말씀해 주세요.
# INFO:conversation_engine:[Router] Current Mode: chat
# INFO:empathy_agent:>>> [Agent Active] Empathy Agent (감성 모드)
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [💬감성대화 | AI]: 알겠습니다. 언제든지 더 이야기하고 싶으실 때 편하게 말씀해 주세요. 오늘 하루를 정리할 수 있는 다이어리를 써드릴까요? 필요하시면 말씀해 주세요. 편안한 시간 보내세요.
#
# [시스템]: 대화를 마무리하며 오늘의 다이어리를 작성했습니다.
#
# **오늘의 다이어리 - 2025년 11월 23일**
#
# 오늘 하루는 그다지 특별한 일 없이 잔잔하게 흘러갔습니다. 주말을 맞아 무엇을 할지 고민했지만, 마음에 드는 활동을 찾기란 쉽지 않았습니다. 다행히 대화 속에서 여러 가지 활동을 제안받으며 잠시나마 가벼운 기분을 느낄 수 있었습니다. 모든 것이 선명하지 않은 하루였지만, 그럼에도 내일은 조금 더 활기찬 시간을 보낼 수 있기를 기대해봅니다.
#
# >>> 테스트를 종료합니다.

# %%
import os
import sys

from conversation_engine import ConversationEngine

def visualize_langgraph():
    # 1. 엔진 초기화 (그래프 빌드)
    engine = ConversationEngine()
    
    # 2. 컴파일된 LangGraph 앱 객체 가져오기
    app = engine.app
    
    # 3. Mermaid 문법으로 출력 (터미널용)
    print("https://mermaid.live/")
    print()
    
    mermaid_code = app.get_graph().draw_mermaid()
    print(mermaid_code)
    
visualize_langgraph()
# Out:
# https://mermaid.live/
#
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	empathy_agent(empathy_agent)
# 	info_agent(info_agent)
# 	tools(tools)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ -.-> empathy_agent;
# 	__start__ -.-> info_agent;
# 	empathy_agent -.-> __end__;
# 	empathy_agent -.-> tools;
# 	tools --> empathy_agent;
# 	info_agent --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
